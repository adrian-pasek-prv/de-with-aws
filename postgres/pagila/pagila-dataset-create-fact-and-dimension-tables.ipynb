# %%
# Load IPython SQL 
# %load_ext sql

# Specify connection details to postgres database
db_host = '127.0.0.1'
db_name = 'pagila'
db_user = 'postgres'
db_password = '123456'
db_port = '5432'

conn_str = f'postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}'
print(conn_str)
# Out:
# postgresql://postgres:123456@127.0.0.1:5432/pagila

# %%
# %sql $conn_str
# Out:
# 'Connected: postgres@pagila'

# %% [markdown]
# ## Create fact and dimension tables

# %%
# Create dimension tables

# dimDate

# %%
# %%sql
# CREATE TABLE dimDate
# (
#   date_key integer NOT NULL PRIMARY KEY,
#   date date NOT NULL,
#   year smallint NOT NULL,
#   quarter smallint NOT NULL,
#   month smallint NOT NULL,
#   day smallint NOT NULL,
#   week smallint NOT NULL,
#   is_weekend boolean
# );
# Out:
#  * postgresql://postgres:***@127.0.0.1:5432/pagila
# Done.
# []

# %%
# %%sql
# SELECT column_name, data_type
# FROM information_schema.columns
# WHERE table_name   = 'dimdate'
# Out:
#  * postgresql://postgres:***@127.0.0.1:5432/pagila
# 8 rows affected.
# [('date_key', 'integer'),
#  ('date', 'date'),
#  ('year', 'smallint'),
#  ('quarter', 'smallint'),
#  ('month', 'smallint'),
#  ('day', 'smallint'),
#  ('week', 'smallint'),
#  ('is_weekend', 'boolean')]

# %%
# dimCustomer, dimMovie, dimStore

# %%
# %%sql
# CREATE TABLE dimCustomer
# (
#   customer_key SERIAL PRIMARY KEY,
#   customer_id  smallint NOT NULL,
#   first_name   varchar(45) NOT NULL,
#   last_name    varchar(45) NOT NULL,
#   email        varchar(50),
#   address      varchar(50) NOT NULL,
#   address2     varchar(50),
#   district     varchar(20) NOT NULL,
#   city         varchar(50) NOT NULL,
#   country      varchar(50) NOT NULL,
#   postal_code  varchar(10),
#   phone        varchar(20) NOT NULL,
#   active       smallint NOT NULL,
#   create_date  timestamp NOT NULL,
#   start_date   date NOT NULL,
#   end_date     date NOT NULL
# );
#
# CREATE TABLE dimMovie
# (
#   movie_key          SERIAL PRIMARY KEY,
#   film_id            smallint NOT NULL,
#   title              varchar(255) NOT NULL,
#   description        text,
#   release_year       year,
#   language           varchar(20) NOT NULL,
#   original_language  varchar(20),
#   rental_duration    smallint NOT NULL,
#   length             smallint NOT NULL,
#   rating             varchar(5) NOT NULL,
#   special_features   varchar(60) NOT NULL
# );
# CREATE TABLE dimStore
# (
#   store_key           SERIAL PRIMARY KEY,
#   store_id            smallint NOT NULL,
#   address             varchar(50) NOT NULL,
#   address2            varchar(50),
#   district            varchar(20) NOT NULL,
#   city                varchar(50) NOT NULL,
#   country             varchar(50) NOT NULL,
#   postal_code         varchar(10),
#   manager_first_name  varchar(45) NOT NULL,
#   manager_last_name   varchar(45) NOT NULL,
#   start_date          date NOT NULL,
#   end_date            date NOT NULL
# );
# Out:
#  * postgresql://postgres:***@127.0.0.1:5432/pagila
# Done.
# Done.
# Done.
# []

# %%
# Create fact tables

# fctSales

# %%
# %%sql
# CREATE TABLE factSales
# (
#     sales_key serial PRIMARY KEY,
#     date_key int REFERENCES dimDate (date_key),
#     customer_key int REFERENCES dimCustomer (customer_key),
#     movie_key int REFERENCES dimMovie (movie_key),
#     store_key int REFERENCES dimStore (store_key),
#     sales_amount numeric NOT NULL
# );
# Out:
#  * postgresql://postgres:***@127.0.0.1:5432/pagila
# Done.
# []

# %%
# %%sql
# SELECT column_name, data_type
# FROM information_schema.columns
# WHERE table_name   = 'factsales'
# Out:
#  * postgresql://postgres:***@127.0.0.1:5432/pagila
# 6 rows affected.
# [('sales_key', 'integer'),
#  ('date_key', 'integer'),
#  ('customer_key', 'integer'),
#  ('movie_key', 'integer'),
#  ('store_key', 'integer'),
#  ('sales_amount', 'numeric')]

# %% [markdown]
# ## Populate fact and dimension tables

# %% [markdown]
# #### dimDate - transformation of payment_date column into dimension columns

# %%
# %%sql
# INSERT INTO dimDate (date_key, date, year, quarter, month, day, week, is_weekend)
# SELECT DISTINCT(TO_CHAR(payment_date :: DATE, 'yyyyMMDD')::integer) AS date_key,
#        date(payment_date)                                           AS date,
#        EXTRACT(year FROM payment_date)                              AS year,
#        EXTRACT(quarter FROM payment_date)                           AS quarter,
#        EXTRACT(month FROM payment_date)                             AS month,
#        EXTRACT(day FROM payment_date)                               AS day,
#        EXTRACT(week FROM payment_date)                              AS week,
#        CASE WHEN EXTRACT(ISODOW FROM payment_date) IN (6, 7) THEN true ELSE false END AS is_weekend
# FROM payment;
# Out:
#  * postgresql://postgres:***@127.0.0.1:5432/pagila
# 186 rows affected.
# []

# %% [markdown]
# #### dim Customer - denormalization

# %%
# %%sql
# INSERT INTO dimCustomer (customer_key, customer_id, first_name, last_name, email, address,
#                          address2, district, city, country, postal_code, phone, active,
#                          create_date, start_date, end_date)
# SELECT
#     c.customer_id as customer_key,
#     c.customer_id,
#     c.first_name,
#     c.last_name,
#     c.email,
#     a.address,
#     a.address2,
#     a.district,
#     ci.city,
#     co.country,
#     a.postal_code,
#     a.phone,
#     c.active,
#     c.create_date,
#     now()         AS start_date,
#     now()         AS end_date
# FROM customer c
# JOIN address a  ON (c.address_id = a.address_id)
# JOIN city ci    ON (a.city_id = ci.city_id)
# JOIN country co ON (ci.country_id = co.country_id);
# Out:
#  * postgresql://postgres:***@127.0.0.1:5432/pagila
# 599 rows affected.
# []

# %% [markdown]
# #### dimMovie - denormalization

# %%
# %%sql
# INSERT INTO dimMovie (movie_key, film_id, title, description, release_year, language, original_language, rental_duration, length, rating, special_features)
# SELECT
#     f.film_id as movie_key,
#     f.film_id,
#     f.title,
#     f.description,
#     f.release_year,
#     l.name as language,
#     orig_lang.name as original_language,
#     f.rental_duration,
#     f.length,
#     f.rating,
#     f.special_features
# FROM film f
# JOIN language l              ON (f.language_id=l.language_id)
# LEFT JOIN language orig_lang ON (f.original_language_id = orig_lang.language_id);
# Out:
#  * postgresql://postgres:***@127.0.0.1:5432/pagila
# 1000 rows affected.
# []

# %% [markdown]
# #### dimStore - denormalization

# %%
# %%sql
# INSERT INTO dimStore (store_key, store_id, address, address2, district, city, country, postal_code, manager_first_name, manager_last_name, start_date, end_date)
# SELECT
#     s.store_id as store_key,
#     s.store_id,
#     a.address,
#     a.address2,
#     a.district,
#     c.city,
#     co.country,
#     a.postal_code,
#     st.first_name as manager_first_name,
#     st.last_name as manager_last_name,
#     now() as start_date,
#     now() as end_date
# FROM store s
# JOIN staff st   ON (s.manager_staff_id = st.staff_id)
# JOIN address a  ON (s.address_id = a.address_id)
# JOIN city c     ON (a.city_id = c.city_id)
# JOIN country co ON (c.country_id = co.country_id);
# Out:
#  * postgresql://postgres:***@127.0.0.1:5432/pagila
# 2 rows affected.
# []

# %% [markdown]
# #### factSales - create a large table of facts with measurements and dimension keys

# %%
# %%sql
# INSERT INTO factSales (date_key, customer_key, movie_key, store_key, sales_amount)
# SELECT
#     to_char(p.payment_date::date, 'yyyyMMDD')::integer   as date_key ,
#     p.customer_id                                        as customer_key,
#     i.film_id                                            as movie_key,
#     i.store_id                                           as store_key,
#     p.amount                                             as sales_amount
# FROM payment p
# JOIN rental r    ON ( p.rental_id = r.rental_id )
# JOIN inventory i ON ( r.inventory_id = i.inventory_id );
# Out:
#  * postgresql://postgres:***@127.0.0.1:5432/pagila
# 16049 rows affected.
# []

# %% [markdown]
# #### Validate data

# %%
# %%sql
# SELECT movie_key, date_key, customer_key, sales_amount
# FROM factSales
# limit 5;
# Out:
#  * postgresql://postgres:***@127.0.0.1:5432/pagila
# 5 rows affected.
# [(651, 20220129, 269, Decimal('0.99')),
#  (138, 20220125, 274, Decimal('2.99')),
#  (186, 20220128, 297, Decimal('0.99')),
#  (197, 20220131, 344, Decimal('2.99')),
#  (741, 20220126, 348, Decimal('0.99'))]

# %% [markdown]
# #### What's the revenue for movie grouped by month and city

# %%
# %%sql
# SELECT dimMovie.title, dimDate.month, dimCustomer.city, sum(sales_amount) as revenue
# FROM factSales
# JOIN dimMovie    on (dimMovie.movie_key      = factSales.movie_key)
# JOIN dimDate     on (dimDate.date_key         = factSales.date_key)
# JOIN dimCustomer on (dimCustomer.customer_key = factSales.customer_key)
# group by (dimMovie.title, dimDate.month, dimCustomer.city)
# order by dimMovie.title, dimDate.month, dimCustomer.city, revenue desc;
# Out:
#  * postgresql://postgres:***@127.0.0.1:5432/pagila
# 16015 rows affected.
# [('ACADEMY DINOSAUR', 1, 'Cianjur', Decimal('1.99')),
#  ('ACADEMY DINOSAUR', 1, 'Nukualofa', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 2, 'Sullana', Decimal('1.99')),
#  ('ACADEMY DINOSAUR', 2, 'Tel Aviv-Jaffa', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 2, 'Udaipur', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 3, 'Celaya', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 3, 'Jos Azueta', Decimal('1.99')),
#  ('ACADEMY DINOSAUR', 3, 'Pjatigorsk', Decimal('1.99')),
#  ('ACADEMY DINOSAUR', 4, 'Kurashiki', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 4, 'Sucre', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 5, 'Livorno', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 5, 'London', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 5, 'San Lorenzo', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 5, 'Sivas', Decimal('3.99')),
#  ('ACADEMY DINOSAUR', 5, 'Vila Velha', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 6, 'Goinia', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 6, 'Hamilton', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 6, 'Lipetsk', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 6, 'Tabriz', Decimal('3.99')),
#  ('ACADEMY DINOSAUR', 7, 'Almirante Brown', Decimal('1.99')),
#  ('ACADEMY DINOSAUR', 7, 'Charlotte Amalie', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 7, 'Kaliningrad', Decimal('0.99')),
#  ('ACADEMY DINOSAUR', 7, 'Rajkot', Decimal('3.99')),
#  ('ACE GOLDFINGER', 2, 'Kumbakonam', Decimal('4.99')),
#  ('ACE GOLDFINGER', 3, 'Balikesir', Decimal('4.99')),
#  ('ACE GOLDFINGER', 3, 'Soshanguve', Decimal('4.99')),
#  ('ACE GOLDFINGER', 4, 'Binzhou', Decimal('8.99')),
#  ('ACE GOLDFINGER', 4, 'Simferopol', Decimal('9.99')),
#  ('ACE GOLDFINGER', 5, 'Pereira', Decimal('8.99')),
#  ('ACE GOLDFINGER', 6, 'Touliu', Decimal('9.99')),
#  ('ADAPTATION HOLES', 1, 'Cayenne', Decimal('2.99')),
#  ('ADAPTATION HOLES', 1, 'Santa Brbara dOeste', Decimal('2.99')),
#  ('ADAPTATION HOLES', 2, 'Coacalco de Berriozbal', Decimal('2.99')),
#  ('ADAPTATION HOLES', 2, 'Sasebo', Decimal('4.99')),
#  ('ADAPTATION HOLES', 4, 'Jodhpur', Decimal('2.99')),
#  ('ADAPTATION HOLES', 4, 'Urawa', Decimal('2.99')),
#  ('ADAPTATION HOLES', 5, 'Ogbomosho', Decimal('2.99')),
#  ('ADAPTATION HOLES', 5, 'Shikarpur', Decimal('2.99')),
#  ('ADAPTATION HOLES', 6, 'al-Qatif', Decimal('2.99')),
#  ('ADAPTATION HOLES', 7, 'Jelets', Decimal('2.99')),
#  ('ADAPTATION HOLES', 7, 'Miraj', Decimal('2.99')),
#  ('ADAPTATION HOLES', 7, 'Salinas', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 1, 'Ciomas', Decimal('5.99')),
#  ('AFFAIR PREJUDICE', 2, 'Aparecida de Goinia', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 2, 'Avellaneda', Decimal('6.99')),
#  ('AFFAIR PREJUDICE', 2, 'Qomsheh', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 3, 'Caracas', Decimal('6.99')),
#  ('AFFAIR PREJUDICE', 3, 'Crdoba', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 3, 's-Hertogenbosch', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 4, 'Malm', Decimal('5.99')),
#  ('AFFAIR PREJUDICE', 4, 'San Felipe de Puerto Plata', Decimal('4.99')),
#  ('AFFAIR PREJUDICE', 5, 'Chiayi', Decimal('4.99')),
#  ('AFFAIR PREJUDICE', 5, 'Lublin', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 5, 'Sokoto', Decimal('4.99')),
#  ('AFFAIR PREJUDICE', 6, 'Caracas', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 6, 'Laiwu', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 6, 'Palghat (Palakkad)', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 6, 'Tuguegarao', Decimal('3.99')),
#  ('AFFAIR PREJUDICE', 7, 'Atinsk', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 7, 'Changzhou', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 7, 'Hidalgo', Decimal('3.99')),
#  ('AFFAIR PREJUDICE', 7, 'Rancagua', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 7, 'Saint-Denis', Decimal('3.99')),
#  ('AFFAIR PREJUDICE', 7, 'Sirjan', Decimal('2.99')),
#  ('AFFAIR PREJUDICE', 7, 'Tiefa', Decimal('2.99')),
#  ('AFRICAN EGG', 2, 'Ivanovo', Decimal('3.99')),
#  ('AFRICAN EGG', 2, 'Jedda', Decimal('4.99')),
#  ('AFRICAN EGG', 2, 'Tokat', Decimal('2.99')),
#  ('AFRICAN EGG', 2, 'York', Decimal('4.99')),
#  ('AFRICAN EGG', 3, 'Kitwe', Decimal('4.99')),
#  ('AFRICAN EGG', 4, 'Jhansi', Decimal('2.99')),
#  ('AFRICAN EGG', 5, 'Smolensk', Decimal('4.99')),
#  ('AFRICAN EGG', 6, 'Okayama', Decimal('3.99')),
#  ('AFRICAN EGG', 6, 'Richmond Hill', Decimal('4.99')),
#  ('AFRICAN EGG', 6, 'Salzburg', Decimal('5.99')),
#  ('AFRICAN EGG', 7, 'al-Manama', Decimal('2.99')),
#  ('AFRICAN EGG', 7, 'Rampur', Decimal('3.99')),
#  ('AGENT TRUMAN', 2, 'Huixquilucan', Decimal('4.99')),
#  ('AGENT TRUMAN', 2, 'Izumisano', Decimal('5.99')),
#  ('AGENT TRUMAN', 2, 'Omdurman', Decimal('7.99')),
#  ('AGENT TRUMAN', 2, 'Pontianak', Decimal('7.99')),
#  ('AGENT TRUMAN', 2, 'Sunnyvale', Decimal('4.99')),
#  ('AGENT TRUMAN', 2, 'Taizz', Decimal('6.99')),
#  ('AGENT TRUMAN', 3, 'Matsue', Decimal('5.99')),
#  ('AGENT TRUMAN', 3, 'Quilmes', Decimal('2.99')),
#  ('AGENT TRUMAN', 3, 'Usak', Decimal('7.99')),
#  ('AGENT TRUMAN', 4, 'Bhilwara', Decimal('8.99')),
#  ('AGENT TRUMAN', 4, 'Chisinau', Decimal('4.99')),
#  ('AGENT TRUMAN', 4, 'Nantou', Decimal('2.99')),
#  ('AGENT TRUMAN', 4, 'Tafuna', Decimal('4.99')),
#  ('AGENT TRUMAN', 5, 'Coatzacoalcos', Decimal('8.99')),
#  ('AGENT TRUMAN', 5, 'Mogiljov', Decimal('6.99')),
#  ('AGENT TRUMAN', 6, 'Antofagasta', Decimal('3.99')),
#  ('AGENT TRUMAN', 6, 'Aurora', Decimal('4.99')),
#  ('AGENT TRUMAN', 6, 'Emeishan', Decimal('3.99')),
#  ('AGENT TRUMAN', 6, 'Luzinia', Decimal('3.99')),
#  ('AGENT TRUMAN', 6, 'Moscow', Decimal('8.99')),
#  ('AGENT TRUMAN', 7, 'Citrus Heights', Decimal('6.99')),
#  ('AIRPLANE SIERRA', 2, 'Iwakuni', Decimal('4.99')),
#  ('AIRPLANE SIERRA', 2, 'Johannesburg', Decimal('7.99')),
#  ('AIRPLANE SIERRA', 2, 'Kuwana', Decimal('4.99')),
#  ('AIRPLANE SIERRA', 3, 'Cavite', Decimal('7.99')),
#  ('AIRPLANE SIERRA', 3, 'Ibirit', Decimal('4.99')),
#  ('AIRPLANE SIERRA', 3, 'Lubumbashi', Decimal('4.99')),
#  ('AIRPLANE SIERRA', 3, 'Yuncheng', Decimal('4.99')),
#  ('AIRPLANE SIERRA', 3, 'Zalantun', Decimal('4.99')),
#  ('AIRPLANE SIERRA', 4, 'Jurez', Decimal('4.99')),
#  ('AIRPLANE SIERRA', 4, 'Salamanca', Decimal('5.99')),
#  ('AIRPLANE SIERRA', 5, 'Bhusawal', Decimal('4.99')),
#  ('AIRPLANE SIERRA', 5, 'Mahajanga', Decimal('5.99')),
#  ('AIRPLANE SIERRA', 5, 's-Hertogenbosch', Decimal('4.99')),
#  ('AIRPLANE SIERRA', 5, 'Tsuyama', Decimal('4.99')),
#  ('AIRPLANE SIERRA', 7, 'Sincelejo', Decimal('4.99')),
#  ('AIRPORT POLLOCK', 2, 'San Juan Bautista Tuxtepec', Decimal('4.99')),
#  ('AIRPORT POLLOCK', 2, 'Vaduz', Decimal('4.99')),
#  ('AIRPORT POLLOCK', 3, 'Lublin', Decimal('6.99')),
#  ('AIRPORT POLLOCK', 4, 'Augusta-Richmond County', Decimal('4.99')),
#  ('AIRPORT POLLOCK', 4, 'Erlangen', Decimal('5.99')),
#  ('AIRPORT POLLOCK', 4, 'Okinawa', Decimal('5.99')),
#  ('AIRPORT POLLOCK', 4, 'Palghat (Palakkad)', Decimal('4.99')),
#  ('AIRPORT POLLOCK', 4, 'Peoria', Decimal('5.99')),
#  ('AIRPORT POLLOCK', 4, 'Taguig', Decimal('4.99')),
#  ('AIRPORT POLLOCK', 5, 'Lilongwe', Decimal('7.99')),
#  ('AIRPORT POLLOCK', 5, 'Portoviejo', Decimal('6.99')),
#  ('AIRPORT POLLOCK', 5, 'Sanaa', Decimal('4.99')),
#  ('AIRPORT POLLOCK', 5, 'Yangor', Decimal('5.99')),
#  ('AIRPORT POLLOCK', 6, 'Dhaka', Decimal('4.99')),
#  ('AIRPORT POLLOCK', 6, 'Fukuyama', Decimal('4.99')),
#  ('AIRPORT POLLOCK', 6, 'Pemalang', Decimal('4.99')),
#  ('AIRPORT POLLOCK', 7, 'Bamenda', Decimal('5.99')),
#  ('AIRPORT POLLOCK', 7, 'Molodetno', Decimal('5.99')),
#  ('ALABAMA DEVIL', 2, 'Halifax', Decimal('7.99')),
#  ('ALABAMA DEVIL', 2, 'Otsu', Decimal('8.99')),
#  ('ALABAMA DEVIL', 2, 'Probolinggo', Decimal('8.99')),
#  ('ALABAMA DEVIL', 3, 'Greensboro', Decimal('5.99')),
#  ('ALABAMA DEVIL', 3, 'Kanazawa', Decimal('4.99')),
#  ('ALABAMA DEVIL', 4, 'Asuncin', Decimal('5.99')),
#  ('ALABAMA DEVIL', 4, 'Changhwa', Decimal('4.99')),
#  ('ALABAMA DEVIL', 4, 'Eskisehir', Decimal('2.99')),
#  ('ALABAMA DEVIL', 6, 'Zaoyang', Decimal('5.99')),
#  ('ALABAMA DEVIL', 7, 'Arlington', Decimal('8.99')),
#  ('ALABAMA DEVIL', 7, 'Mit Ghamr', Decimal('2.99')),
#  ('ALABAMA DEVIL', 7, 'Sunnyvale', Decimal('2.99')),
#  ('ALADDIN CALENDAR', 1, 'Balaiha', Decimal('6.99')),
#  ('ALADDIN CALENDAR', 3, 'Esfahan', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 3, 'Halisahar', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 3, 'Hodeida', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 3, 'Kisumu', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 3, 'La Plata', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 3, 'Okinawa', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 3, 'Ranchi', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 3, 'Zalantun', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 4, 'Mwanza', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 4, 'Olomouc', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 5, 'Deba Habe', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 5, 'Izumisano', Decimal('7.99')),
#  ('ALADDIN CALENDAR', 5, 'Sogamoso', Decimal('7.99')),
#  ('ALADDIN CALENDAR', 6, 'Coacalco de Berriozbal', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 6, 'Effon-Alaiye', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 6, 'Kaduna', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 6, 'Valencia', Decimal('7.99')),
#  ('ALADDIN CALENDAR', 7, 'Adoni', Decimal('6.99')),
#  ('ALADDIN CALENDAR', 7, 'Dos Quebradas', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 7, 'Gulbarga', Decimal('7.99')),
#  ('ALADDIN CALENDAR', 7, 'Monclova', Decimal('4.99')),
#  ('ALADDIN CALENDAR', 7, 'Stockport', Decimal('5.99')),
#  ('ALAMO VIDEOTAPE', 1, 'Pemalang', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 2, 'Idfu', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 2, 'Ife', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 2, 'Jinchang', Decimal('1.99')),
#  ('ALAMO VIDEOTAPE', 2, 'Lapu-Lapu', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 2, 'Owo', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 2, 'Tarlac', Decimal('1.99')),
#  ('ALAMO VIDEOTAPE', 3, 'Lapu-Lapu', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 4, 'Papeete', Decimal('1.99')),
#  ('ALAMO VIDEOTAPE', 5, 'Baicheng', Decimal('1.99')),
#  ('ALAMO VIDEOTAPE', 5, 'Emmen', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 5, 'Grand Prairie', Decimal('1.99')),
#  ('ALAMO VIDEOTAPE', 5, 'Meixian', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 5, 'Pudukkottai', Decimal('3.99')),
#  ('ALAMO VIDEOTAPE', 5, 'Rio Claro', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 5, 'Zeleznogorsk', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 6, 'Arecibo', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 6, 'Myingyan', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 6, 'Stara Zagora', Decimal('1.99')),
#  ('ALAMO VIDEOTAPE', 6, 'Tanauan', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 6, 'Yuzhou', Decimal('3.99')),
#  ('ALAMO VIDEOTAPE', 7, 'Bat Yam', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 7, 'Berhampore (Baharampur)', Decimal('0.99')),
#  ('ALAMO VIDEOTAPE', 7, 'Duisburg', Decimal('0.99')),
#  ('ALASKA PHANTOM', 1, 'Dhule (Dhulia)', Decimal('0.99')),
#  ('ALASKA PHANTOM', 1, 'Xiangtan', Decimal('1.99')),
#  ('ALASKA PHANTOM', 2, 'Laohekou', Decimal('1.99')),
#  ('ALASKA PHANTOM', 2, 'Niznekamsk', Decimal('2.99')),
#  ('ALASKA PHANTOM', 2, 'Sterling Heights', Decimal('1.99')),
#  ('ALASKA PHANTOM', 2, 'Zhezqazghan', Decimal('0.99')),
#  ('ALASKA PHANTOM', 3, 'Baicheng', Decimal('0.99')),
#  ('ALASKA PHANTOM', 3, 'Lhokseumawe', Decimal('1.99')),
#  ('ALASKA PHANTOM', 3, 'Maring', Decimal('0.99')),
#  ('ALASKA PHANTOM', 3, 'Peoria', Decimal('3.99')),
#  ('ALASKA PHANTOM', 3, 'Saint Louis', Decimal('0.99')),
#  ('ALASKA PHANTOM', 3, 'Szkesfehrvr', Decimal('1.99')),
#  ('ALASKA PHANTOM', 4, 'Braslia', Decimal('2.99')),
#  ('ALASKA PHANTOM', 4, 'Nantou', Decimal('0.99')),
#  ('ALASKA PHANTOM', 4, 'Touliu', Decimal('0.99')),
#  ('ALASKA PHANTOM', 5, 'al-Qadarif', Decimal('0.99')),
#  ('ALASKA PHANTOM', 5, 'Dhule (Dhulia)', Decimal('2.99')),
#  ('ALASKA PHANTOM', 5, 'Nabereznyje Telny', Decimal('0.99')),
#  ('ALASKA PHANTOM', 5, 'Omdurman', Decimal('0.99')),
#  ('ALASKA PHANTOM', 5, 'Tiefa', Decimal('0.99')),
#  ('ALASKA PHANTOM', 6, 'al-Hawiya', Decimal('0.99')),
#  ('ALASKA PHANTOM', 6, 'Ljubertsy', Decimal('0.99')),
#  ('ALASKA PHANTOM', 6, 'Mandi Bahauddin', Decimal('0.99')),
#  ('ALASKA PHANTOM', 6, 'Nezahualcyotl', Decimal('0.99')),
#  ('ALASKA PHANTOM', 7, 'Bhilwara', Decimal('3.99')),
#  ('ALASKA PHANTOM', 7, 'Zhezqazghan', Decimal('2.99')),
#  ('ALIEN CENTER', 2, 'El Fuerte', Decimal('4.99')),
#  ('ALIEN CENTER', 2, 'Huejutla de Reyes', Decimal('2.99')),
#  ('ALIEN CENTER', 2, 'Lengshuijiang', Decimal('2.99')),
#  ('ALIEN CENTER', 2, 'Songkhla', Decimal('2.99')),
#  ('ALIEN CENTER', 3, 'Bag', Decimal('2.99')),
#  ('ALIEN CENTER', 3, 'Nagareyama', Decimal('2.99')),
#  ('ALIEN CENTER', 3, 'San Felipe de Puerto Plata', Decimal('5.99')),
#  ('ALIEN CENTER', 3, 'Xiangfan', Decimal('6.99')),
#  ('ALIEN CENTER', 4, 'Escobar', Decimal('2.99')),
#  ('ALIEN CENTER', 4, 'Hsichuh', Decimal('2.99')),
#  ('ALIEN CENTER', 5, 'Baiyin', Decimal('2.99')),
#  ('ALIEN CENTER', 5, 'Cuman', Decimal('2.99')),
#  ('ALIEN CENTER', 5, 'Emeishan', Decimal('6.99')),
#  ('ALIEN CENTER', 5, 'Juazeiro do Norte', Decimal('3.99')),
#  ('ALIEN CENTER', 5, 'Rancagua', Decimal('4.99')),
#  ('ALIEN CENTER', 5, 'Sanya', Decimal('4.99')),
#  ('ALIEN CENTER', 5, 'Zhezqazghan', Decimal('5.99')),
#  ('ALIEN CENTER', 6, 'Shahr-e Kord', Decimal('2.99')),
#  ('ALIEN CENTER', 7, 'Caracas', Decimal('2.99')),
#  ('ALIEN CENTER', 7, 'Kragujevac', Decimal('2.99')),
#  ('ALIEN CENTER', 7, 'Memphis', Decimal('6.99')),
#  ('ALIEN CENTER', 7, 'Richmond Hill', Decimal('2.99')),
#  ('ALI FOREVER', 2, 'Jakarta', Decimal('4.99')),
#  ('ALI FOREVER', 3, 'Esfahan', Decimal('5.99')),
#  ('ALI FOREVER', 3, 'Maikop', Decimal('5.99')),
#  ('ALI FOREVER', 3, 'Ourense (Orense)', Decimal('9.99')),
#  ('ALI FOREVER', 4, 'Lubumbashi', Decimal('4.99')),
#  ('ALI FOREVER', 4, 'Sharja', Decimal('4.99')),
#  ('ALI FOREVER', 6, 'Cuauhtmoc', Decimal('7.99')),
#  ('ALI FOREVER', 6, 'Huixquilucan', Decimal('4.99')),
#  ('ALI FOREVER', 7, 'Vaduz', Decimal('4.99')),
#  ('ALLEY EVOLUTION', 1, 'Tonghae', Decimal('4.99')),
#  ('ALLEY EVOLUTION', 1, 'Tuguegarao', Decimal('2.99')),
#  ('ALLEY EVOLUTION', 3, 'Aden', Decimal('4.99')),
#  ('ALLEY EVOLUTION', 3, 'Mexicali', Decimal('6.99')),
#  ('ALLEY EVOLUTION', 3, 'NDjamna', Decimal('2.99')),
#  ('ALLEY EVOLUTION', 4, 'Esfahan', Decimal('2.99')),
#  ('ALLEY EVOLUTION', 4, 'Kalisz', Decimal('2.99')),
#  ('ALLEY EVOLUTION', 4, 'Lancaster', Decimal('2.99')),
#  ('ALLEY EVOLUTION', 4, 'Ponce', Decimal('2.99')),
#  ('ALLEY EVOLUTION', 4, 'Shahr-e Kord', Decimal('2.99')),
#  ('ALLEY EVOLUTION', 4, 'Shikarpur', Decimal('2.99')),
#  ('ALLEY EVOLUTION', 4, 'Tsaotun', Decimal('2.99')),
#  ('ALLEY EVOLUTION', 5, 'Jos Azueta', Decimal('2.99')),
#  ('ALLEY EVOLUTION', 5, 'Najafabad', Decimal('5.99')),
#  ('ALONE TRIP', 1, 'Sterling Heights', Decimal('4.99')),
#  ('ALONE TRIP', 1, 'Syktyvkar', Decimal('6.99')),
#  ('ALONE TRIP', 2, 'Kamjanets-Podilskyi', Decimal('3.99')),
#  ('ALONE TRIP', 2, 'Sincelejo', Decimal('2.99')),
#  ('ALONE TRIP', 3, 'Arak', Decimal('0.99')),
#  ('ALONE TRIP', 3, 'Cabuyao', Decimal('1.99')),
#  ('ALONE TRIP', 3, 'Hami', Decimal('6.99')),
#  ('ALONE TRIP', 4, 'Huixquilucan', Decimal('4.99')),
#  ('ALONE TRIP', 4, 'NDjamna', Decimal('0.99')),
#  ('ALONE TRIP', 4, 'Tuguegarao', Decimal('3.99')),
#  ('ALONE TRIP', 5, 'Almirante Brown', Decimal('0.99')),
#  ('ALONE TRIP', 5, 'Arecibo', Decimal('1.99')),
#  ('ALONE TRIP', 5, 'Mwanza', Decimal('6.99')),
#  ('ALONE TRIP', 5, 'Sousse', Decimal('4.99')),
#  ('ALONE TRIP', 5, 'Tanza', Decimal('0.99')),
#  ('ALONE TRIP', 6, 'Lungtan', Decimal('2.99')),
#  ('ALONE TRIP', 6, 'Tarsus', Decimal('2.99')),
#  ('ALONE TRIP', 7, 'Vinh', Decimal('1.99')),
#  ('ALTER VICTORY', 1, 'Addis Abeba', Decimal('1.99')),
#  ('ALTER VICTORY', 2, 'Cianjur', Decimal('0.99')),
#  ('ALTER VICTORY', 2, 'Kitwe', Decimal('3.99')),
#  ('ALTER VICTORY', 3, 'Bandar Seri Begawan', Decimal('0.99')),
#  ('ALTER VICTORY', 3, 'Bijapur', Decimal('0.99')),
#  ('ALTER VICTORY', 3, 'Shimonoseki', Decimal('0.99')),
#  ('ALTER VICTORY', 3, 'Urawa', Decimal('0.99')),
#  ('ALTER VICTORY', 4, 'Charlotte Amalie', Decimal('0.99')),
#  ('ALTER VICTORY', 4, 'Meixian', Decimal('0.99')),
#  ('ALTER VICTORY', 4, 'Tongliao', Decimal('1.99')),
#  ('ALTER VICTORY', 5, 'Ezhou', Decimal('0.99')),
#  ('ALTER VICTORY', 5, 'Korolev', Decimal('0.99')),
#  ('ALTER VICTORY', 5, 'Purnea (Purnia)', Decimal('0.99')),
#  ('ALTER VICTORY', 5, 'Sirjan', Decimal('3.99')),
#  ('ALTER VICTORY', 5, 'Vinh', Decimal('0.99')),
#  ('ALTER VICTORY', 6, 'Alessandria', Decimal('0.99')),
#  ('ALTER VICTORY', 6, 'Avellaneda', Decimal('0.99')),
#  ('ALTER VICTORY', 6, 'Kamyin', Decimal('0.99')),
#  ('ALTER VICTORY', 6, 'Nantou', Decimal('0.99')),
#  ('ALTER VICTORY', 6, 'Shaoguan', Decimal('3.99')),
#  ('ALTER VICTORY', 6, 'Tiefa', Decimal('0.99')),
#  ('ALTER VICTORY', 7, 'Boksburg', Decimal('0.99')),
#  ('AMADEUS HOLY', 1, 'Joliet', Decimal('3.99')),
#  ('AMADEUS HOLY', 2, 'Hohhot', Decimal('1.99')),
#  ('AMADEUS HOLY', 2, 'La Plata', Decimal('0.99')),
#  ('AMADEUS HOLY', 2, 'Laredo', Decimal('0.99')),
#  ('AMADEUS HOLY', 3, 'Bilbays', Decimal('1.99')),
#  ('AMADEUS HOLY', 4, 'Arak', Decimal('0.99')),
#  ('AMADEUS HOLY', 4, 'Denizli', Decimal('0.99')),
#  ('AMADEUS HOLY', 4, 'Jakarta', Decimal('0.99')),
#  ('AMADEUS HOLY', 4, 'London', Decimal('0.99')),
#  ('AMADEUS HOLY', 4, 'Vila Velha', Decimal('0.99')),
#  ('AMADEUS HOLY', 5, 'Citt del Vaticano', Decimal('1.99')),
#  ('AMADEUS HOLY', 5, 'Myingyan', Decimal('0.99')),
#  ('AMADEUS HOLY', 6, 'Araatuba', Decimal('0.99')),
#  ('AMADEUS HOLY', 6, 'Jining', Decimal('0.99')),
#  ('AMADEUS HOLY', 6, 'Kurashiki', Decimal('0.99')),
#  ('AMADEUS HOLY', 6, 'Matamoros', Decimal('0.99')),
#  ('AMADEUS HOLY', 6, 'Nabereznyje Telny', Decimal('0.99')),
#  ('AMADEUS HOLY', 6, 'Pjatigorsk', Decimal('0.99')),
#  ('AMADEUS HOLY', 6, 'Poos de Caldas', Decimal('3.99')),
#  ('AMADEUS HOLY', 6, 'Shubra al-Khayma', Decimal('3.99')),
#  ('AMADEUS HOLY', 7, 'Warren', Decimal('1.99')),
#  ('AMELIE HELLFIGHTERS', 3, 'Acua', Decimal('4.99')),
#  ('AMELIE HELLFIGHTERS', 3, 'Meixian', Decimal('6.99')),
#  ('AMELIE HELLFIGHTERS', 3, 'Tonghae', Decimal('8.99')),
#  ('AMELIE HELLFIGHTERS', 4, 'Madiun', Decimal('4.99')),
#  ('AMELIE HELLFIGHTERS', 5, 'Anpolis', Decimal('4.99')),
#  ('AMELIE HELLFIGHTERS', 5, 'Funafuti', Decimal('9.99')),
#  ('AMELIE HELLFIGHTERS', 6, 'Botshabelo', Decimal('5.99')),
#  ('AMELIE HELLFIGHTERS', 6, 'Sterling Heights', Decimal('4.99')),
#  ('AMELIE HELLFIGHTERS', 7, 'Ipoh', Decimal('5.99')),
#  ('AMELIE HELLFIGHTERS', 7, 'So Bernardo do Campo', Decimal('9.99')),
#  ('AMERICAN CIRCUS', 1, 'El Fuerte', Decimal('6.99')),
#  ('AMERICAN CIRCUS', 2, 'Bijapur', Decimal('10.99')),
#  ('AMERICAN CIRCUS', 2, 'Imus', Decimal('4.99')),
#  ('AMERICAN CIRCUS', 2, 'Konotop', Decimal('10.99')),
#  ('AMERICAN CIRCUS', 2, 'Nador', Decimal('8.99')),
#  ('AMERICAN CIRCUS', 2, 'Oulu', Decimal('4.99')),
#  ('AMERICAN CIRCUS', 2, 'Tiefa', Decimal('8.99')),
#  ('AMERICAN CIRCUS', 3, 'Benguela', Decimal('9.99')),
#  ('AMERICAN CIRCUS', 3, 'Juazeiro do Norte', Decimal('14.98')),
#  ('AMERICAN CIRCUS', 3, 'Nagaon', Decimal('4.99')),
#  ('AMERICAN CIRCUS', 4, 'Bergamo', Decimal('5.99')),
#  ('AMERICAN CIRCUS', 4, 'Bydgoszcz', Decimal('4.99')),
#  ('AMERICAN CIRCUS', 4, 'Dos Quebradas', Decimal('9.99')),
#  ('AMERICAN CIRCUS', 4, 'Oulu', Decimal('4.99')),
#  ('AMERICAN CIRCUS', 5, 'Callao', Decimal('10.99')),
#  ('AMERICAN CIRCUS', 5, 'Halle/Saale', Decimal('8.99')),
#  ('AMERICAN CIRCUS', 5, 'Saint-Denis', Decimal('10.99')),
#  ('AMERICAN CIRCUS', 6, 'Bayugan', Decimal('4.99')),
#  ('AMERICAN CIRCUS', 6, 'Cabuyao', Decimal('8.99')),
#  ('AMERICAN CIRCUS', 7, 'Changhwa', Decimal('4.99')),
#  ('AMERICAN CIRCUS', 7, 'Lipetsk', Decimal('4.99')),
#  ('AMISTAD MIDSUMMER', 1, 'Shimonoseki', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 1, 'Usak', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 1, 'Vijayawada', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 2, 'Cavite', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 2, 'Garland', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 2, 'Mysore', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 2, 'Nantou', Decimal('3.99')),
#  ('AMISTAD MIDSUMMER', 2, 'Sasebo', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 2, 'Xinxiang', Decimal('3.99')),
#  ('AMISTAD MIDSUMMER', 3, 'Imus', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 3, 'Jastrzebie-Zdrj', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 3, 'Miyakonojo', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 4, 'Akron', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 4, 'Avellaneda', Decimal('4.99')),
#  ('AMISTAD MIDSUMMER', 4, 'Kolpino', Decimal('3.99')),
#  ('AMISTAD MIDSUMMER', 5, 'Elista', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 6, 'Apeldoorn', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 6, 'Arecibo', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 6, 'Effon-Alaiye', Decimal('5.99')),
#  ('AMISTAD MIDSUMMER', 7, 's-Hertogenbosch', Decimal('2.99')),
#  ('AMISTAD MIDSUMMER', 7, 'Zanzibar', Decimal('2.99')),
#  ('ANACONDA CONFESSIONS', 1, 'Jelets', Decimal('1.99')),
#  ('ANACONDA CONFESSIONS', 2, 'Batman', Decimal('5.99')),
#  ('ANACONDA CONFESSIONS', 2, 'Haldia', Decimal('0.99')),
#  ('ANACONDA CONFESSIONS', 2, 'Kermanshah', Decimal('1.99')),
#  ('ANACONDA CONFESSIONS', 2, 'Roanoke', Decimal('5.99')),
#  ('ANACONDA CONFESSIONS', 3, 'Athenai', Decimal('6.99')),
#  ('ANACONDA CONFESSIONS', 3, 'Molodetno', Decimal('3.99')),
#  ('ANACONDA CONFESSIONS', 3, 'Shanwei', Decimal('2.99')),
#  ('ANACONDA CONFESSIONS', 3, 'Tanza', Decimal('3.99')),
#  ('ANACONDA CONFESSIONS', 4, 'Caracas', Decimal('1.99')),
#  ('ANACONDA CONFESSIONS', 4, 'Nanyang', Decimal('3.99')),
#  ('ANACONDA CONFESSIONS', 4, 'Vitria de Santo Anto', Decimal('0.99')),
#  ('ANACONDA CONFESSIONS', 5, 'Charlotte Amalie', Decimal('0.99')),
#  ('ANACONDA CONFESSIONS', 5, 'Dallas', Decimal('0.99')),
#  ('ANACONDA CONFESSIONS', 5, 'Otsu', Decimal('5.99')),
#  ('ANACONDA CONFESSIONS', 5, 'Sambhal', Decimal('2.99')),
#  ('ANACONDA CONFESSIONS', 6, 'Botshabelo', Decimal('0.99')),
#  ('ANACONDA CONFESSIONS', 6, 'Fengshan', Decimal('0.99')),
#  ('ANACONDA CONFESSIONS', 6, 'San Juan Bautista Tuxtepec', Decimal('2.99')),
#  ('ANACONDA CONFESSIONS', 6, 'Tarsus', Decimal('1.99')),
#  ('ANACONDA CONFESSIONS', 7, 'Uttarpara-Kotrung', Decimal('0.99')),
#  ('ANALYZE HOOSIERS', 1, 'Bijapur', Decimal('3.99')),
#  ('ANALYZE HOOSIERS', 1, 'Valparai', Decimal('3.99')),
#  ('ANALYZE HOOSIERS', 3, 'Ciudad del Este', Decimal('2.99')),
#  ('ANALYZE HOOSIERS', 3, 'Usak', Decimal('2.99')),
#  ('ANALYZE HOOSIERS', 3, 'Xintai', Decimal('2.99')),
#  ('ANALYZE HOOSIERS', 4, 'Joliet', Decimal('2.99')),
#  ('ANALYZE HOOSIERS', 5, 'Citrus Heights', Decimal('4.99')),
#  ('ANALYZE HOOSIERS', 5, 'Saint Louis', Decimal('4.99')),
#  ('ANALYZE HOOSIERS', 6, 'Ambattur', Decimal('4.99')),
#  ('ANALYZE HOOSIERS', 6, 'Celaya', Decimal('3.99')),
#  ('ANALYZE HOOSIERS', 6, 'Kurashiki', Decimal('5.99')),
#  ('ANALYZE HOOSIERS', 6, 'Tartu', Decimal('4.99')),
#  ('ANALYZE HOOSIERS', 7, 'Kuwana', Decimal('2.99')),
#  ('ANALYZE HOOSIERS', 7, 'Yuncheng', Decimal('2.99')),
#  ('ANGELS LIFE', 2, 'Kermanshah', Decimal('3.99')),
#  ('ANGELS LIFE', 2, 'Olomouc', Decimal('2.99')),
#  ('ANGELS LIFE', 3, 'Arecibo', Decimal('3.99')),
#  ('ANGELS LIFE', 3, 'Carmen', Decimal('5.99')),
#  ('ANGELS LIFE', 3, 'Korolev', Decimal('7.99')),
#  ('ANGELS LIFE', 3, 'San Juan Bautista Tuxtepec', Decimal('6.99')),
#  ('ANGELS LIFE', 3, 'York', Decimal('2.99')),
#  ('ANGELS LIFE', 4, 'Ambattur', Decimal('2.99')),
#  ('ANGELS LIFE', 4, 'Sharja', Decimal('6.99')),
#  ('ANGELS LIFE', 4, 'Wroclaw', Decimal('7.99')),
#  ('ANGELS LIFE', 5, 'Augusta-Richmond County', Decimal('2.99')),
#  ('ANGELS LIFE', 5, 'Greensboro', Decimal('2.99')),
#  ('ANGELS LIFE', 5, 'Kakamigahara', Decimal('3.99')),
#  ('ANGELS LIFE', 6, 'Kakamigahara', Decimal('2.99')),
#  ('ANGELS LIFE', 6, 'Nagareyama', Decimal('5.99')),
#  ('ANGELS LIFE', 6, 'Salala', Decimal('8.99')),
#  ('ANGELS LIFE', 6, 'Salamanca', Decimal('8.99')),
#  ('ANGELS LIFE', 6, 'Teboksary', Decimal('6.99')),
#  ('ANGELS LIFE', 6, 'Urawa', Decimal('2.99')),
#  ('ANGELS LIFE', 7, 'Adana', Decimal('6.99')),
#  ('ANGELS LIFE', 7, 'Fukuyama', Decimal('3.99')),
#  ('ANGELS LIFE', 7, 'Rampur', Decimal('8.99')),
#  ('ANNIE IDENTITY', 1, 'Ashqelon', Decimal('4.99')),
#  ('ANNIE IDENTITY', 1, 'Ede', Decimal('5.99')),
#  ('ANNIE IDENTITY', 1, 'Santa F', Decimal('2.99')),
#  ('ANNIE IDENTITY', 1, 'Tama', Decimal('0.99')),
#  ('ANNIE IDENTITY', 2, 'Oyo', Decimal('0.99')),
#  ('ANNIE IDENTITY', 2, 'Zhoushan', Decimal('2.99')),
#  ('ANNIE IDENTITY', 3, 'Czestochowa', Decimal('4.99')),
#  ('ANNIE IDENTITY', 3, 'Luzinia', Decimal('0.99')),
#  ('ANNIE IDENTITY', 3, 'Pangkal Pinang', Decimal('0.99')),
#  ('ANNIE IDENTITY', 3, 'Tel Aviv-Jaffa', Decimal('0.99')),
#  ('ANNIE IDENTITY', 4, 'Battambang', Decimal('2.99')),
#  ('ANNIE IDENTITY', 4, 'Cabuyao', Decimal('0.99')),
#  ('ANNIE IDENTITY', 4, 'Szkesfehrvr', Decimal('0.99')),
#  ('ANNIE IDENTITY', 4, 'Yuncheng', Decimal('0.99')),
#  ('ANNIE IDENTITY', 4, 'Zaria', Decimal('5.99')),
#  ('ANNIE IDENTITY', 5, 'Shaoguan', Decimal('6.99')),
#  ('ANNIE IDENTITY', 6, 'Jedda', Decimal('3.99')),
#  ('ANNIE IDENTITY', 6, 'Maring', Decimal('3.99')),
#  ('ANNIE IDENTITY', 6, 'Myingyan', Decimal('1.99')),
#  ('ANNIE IDENTITY', 6, 'Vilnius', Decimal('1.99')),
#  ('ANNIE IDENTITY', 7, 'Goinia', Decimal('0.99')),
#  ('ANNIE IDENTITY', 7, 'Zanzibar', Decimal('0.99')),
#  ('ANONYMOUS HUMAN', 2, 'Basel', Decimal('0.99')),
#  ('ANONYMOUS HUMAN', 2, 'Uruapan', Decimal('1.99')),
#  ('ANONYMOUS HUMAN', 2, 'Varanasi (Benares)', Decimal('0.99')),
#  ('ANONYMOUS HUMAN', 3, 'Kamakura', Decimal('1.99')),
#  ('ANONYMOUS HUMAN', 3, 'Liepaja', Decimal('0.99')),
#  ('ANONYMOUS HUMAN', 3, 'Richmond Hill', Decimal('0.99')),
#  ('ANONYMOUS HUMAN', 4, 'Dhaka', Decimal('0.99')),
#  ('ANONYMOUS HUMAN', 4, 'Kowloon and New Kowloon', Decimal('0.99')),
#  ('ANONYMOUS HUMAN', 4, 'San Bernardino', Decimal('0.99')),
#  ('ANONYMOUS HUMAN', 6, 'Ezhou', Decimal('2.99')),
#  ('ANONYMOUS HUMAN', 6, 'Iwakuni', Decimal('0.99')),
#  ('ANONYMOUS HUMAN', 6, 'Zhezqazghan', Decimal('1.99')),
#  ('ANONYMOUS HUMAN', 7, 'La Romana', Decimal('0.99')),
#  ('ANTHEM LUKE', 2, 'Acua', Decimal('4.99')),
#  ('ANTHEM LUKE', 2, 'Lengshuijiang', Decimal('6.99')),
#  ('ANTHEM LUKE', 2, 'Lhokseumawe', Decimal('8.99')),
#  ('ANTHEM LUKE', 2, 'Uluberia', Decimal('4.99')),
#  ('ANTHEM LUKE', 3, 'Changzhou', Decimal('4.99')),
#  ('ANTHEM LUKE', 3, 'Ozamis', Decimal('4.99')),
#  ('ANTHEM LUKE', 3, 'San Felipe del Progreso', Decimal('4.99')),
#  ('ANTHEM LUKE', 4, 'Fukuyama', Decimal('4.99')),
#  ('ANTHEM LUKE', 5, 'Boa Vista', Decimal('8.99')),
#  ('ANTHEM LUKE', 5, 'Kuwana', Decimal('5.99')),
#  ('ANTHEM LUKE', 6, 'Ashgabat', Decimal('4.99')),
#  ('ANTHEM LUKE', 6, 'Cuauhtmoc', Decimal('4.99')),
#  ('ANTHEM LUKE', 6, 'Pyongyang', Decimal('4.99')),
#  ('ANTHEM LUKE', 7, 'Coacalco de Berriozbal', Decimal('4.99')),
#  ('ANTHEM LUKE', 7, 'Kirovo-Tepetsk', Decimal('4.99')),
#  ('ANTITRUST TOMATOES', 2, 'Bhimavaram', Decimal('3.99')),
#  ('ANTITRUST TOMATOES', 2, 'Vijayawada', Decimal('2.99')),
#  ('ANTITRUST TOMATOES', 3, 'Fuyu', Decimal('4.99')),
#  ('ANTITRUST TOMATOES', 3, 'Novoterkassk', Decimal('2.99')),
#  ('ANTITRUST TOMATOES', 5, 'Malm', Decimal('2.99')),
#  ('ANTITRUST TOMATOES', 5, 'Sharja', Decimal('3.99')),
#  ('ANTITRUST TOMATOES', 6, 'Pereira', Decimal('2.99')),
#  ('ANTITRUST TOMATOES', 6, 'Ziguinchor', Decimal('2.99')),
#  ('ANTITRUST TOMATOES', 7, 'Erlangen', Decimal('2.99')),
#  ('ANTITRUST TOMATOES', 7, 'Lapu-Lapu', Decimal('6.99')),
#  ('ANYTHING SAVANNAH', 2, 'Mexicali', Decimal('6.99')),
#  ('ANYTHING SAVANNAH', 2, 'Yangor', Decimal('7.99')),
#  ('ANYTHING SAVANNAH', 3, 'Zaoyang', Decimal('2.99')),
#  ('ANYTHING SAVANNAH', 5, 'El Monte', Decimal('5.99')),
#  ('ANYTHING SAVANNAH', 6, 'Araatuba', Decimal('4.99')),
#  ('ANYTHING SAVANNAH', 6, 'Banjul', Decimal('7.99')),
#  ('ANYTHING SAVANNAH', 7, 'Cam Ranh', Decimal('3.99')),
#  ('ANYTHING SAVANNAH', 7, 'Gandhinagar', Decimal('2.99')),
#  ('ANYTHING SAVANNAH', 7, 'Halle/Saale', Decimal('2.99')),
#  ('APACHE DIVINE', 2, 'Cavite', Decimal('4.99')),
#  ('APACHE DIVINE', 2, 'Iwaki', Decimal('4.99')),
#  ('APACHE DIVINE', 2, 'Kanazawa', Decimal('4.99')),
#  ('APACHE DIVINE', 2, 'Robamba', Decimal('4.99')),
#  ('APACHE DIVINE', 2, 'So Leopoldo', Decimal('4.99')),
#  ('APACHE DIVINE', 3, 'Bandar Seri Begawan', Decimal('4.99')),
#  ('APACHE DIVINE', 3, 'Carmen', Decimal('4.99')),
#  ('APACHE DIVINE', 3, 'Greensboro', Decimal('4.99')),
#  ('APACHE DIVINE', 3, 'Moscow', Decimal('5.99')),
#  ('APACHE DIVINE', 3, 'Mukateve', Decimal('7.99')),
#  ('APACHE DIVINE', 3, 'Okinawa', Decimal('8.99')),
#  ('APACHE DIVINE', 3, 'York', Decimal('7.99')),
#  ('APACHE DIVINE', 4, 'Balikesir', Decimal('6.99')),
#  ('APACHE DIVINE', 4, 'El Fuerte', Decimal('6.99')),
#  ('APACHE DIVINE', 4, 'Guadalajara', Decimal('4.99')),
#  ('APACHE DIVINE', 4, 'Oshawa', Decimal('4.99')),
#  ('APACHE DIVINE', 4, 'Sorocaba', Decimal('4.99')),
#  ('APACHE DIVINE', 4, 'Taguig', Decimal('5.99')),
#  ('APACHE DIVINE', 4, 'Taizz', Decimal('4.99')),
#  ('APACHE DIVINE', 4, 'Zanzibar', Decimal('4.99')),
#  ('APACHE DIVINE', 5, 'Malm', Decimal('4.99')),
#  ('APACHE DIVINE', 6, 'Bamenda', Decimal('4.99')),
#  ('APACHE DIVINE', 6, 'Jaffna', Decimal('4.99')),
#  ('APACHE DIVINE', 6, 'Kimberley', Decimal('5.99')),
#  ('APACHE DIVINE', 6, 'Pereira', Decimal('5.99')),
#  ('APACHE DIVINE', 6, 'Tiefa', Decimal('4.99')),
#  ('APACHE DIVINE', 6, 'Urawa', Decimal('4.99')),
#  ('APACHE DIVINE', 7, 'Boksburg', Decimal('7.99')),
#  ('APACHE DIVINE', 7, 'Cam Ranh', Decimal('4.99')),
#  ('APACHE DIVINE', 7, 'Maikop', Decimal('5.99')),
#  ('APACHE DIVINE', 7, 'Mit Ghamr', Decimal('6.99')),
#  ('APOCALYPSE FLAMINGOS', 2, 'Kalisz', Decimal('5.99')),
#  ('APOCALYPSE FLAMINGOS', 3, 'Blumenau', Decimal('4.99')),
#  ('APOCALYPSE FLAMINGOS', 3, 'Chandrapur', Decimal('4.99')),
#  ('APOCALYPSE FLAMINGOS', 5, 'Belm', Decimal('4.99')),
#  ('APOCALYPSE FLAMINGOS', 5, 'Ikerre', Decimal('4.99')),
#  ('APOCALYPSE FLAMINGOS', 7, 'Ruse', Decimal('4.99')),
#  ('ARABIA DOGMA', 2, 'Amroha', Decimal('0.99')),
#  ('ARABIA DOGMA', 4, 'Lubumbashi', Decimal('0.99')),
#  ('ARABIA DOGMA', 4, 'Monclova', Decimal('3.99')),
#  ('ARABIA DOGMA', 4, 'Toulouse', Decimal('0.99')),
#  ('ARABIA DOGMA', 5, 'La Plata', Decimal('3.99')),
#  ('ARABIA DOGMA', 5, 'Usak', Decimal('0.99')),
#  ('ARABIA DOGMA', 6, 'Tartu', Decimal('0.99')),
#  ('ARABIA DOGMA', 6, 'Tuguegarao', Decimal('0.99')),
#  ('ARABIA DOGMA', 7, 'Changzhou', Decimal('0.99')),
#  ('ARABIA DOGMA', 7, 'Lapu-Lapu', Decimal('0.99')),
#  ('ARABIA DOGMA', 7, 'London', Decimal('3.99')),
#  ('ARABIA DOGMA', 7, 'Qalyub', Decimal('0.99')),
#  ('ARABIA DOGMA', 7, 'Tokat', Decimal('1.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 1, 'Bhusawal', Decimal('2.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 1, 'Ondo', Decimal('6.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 1, 'Usak', Decimal('5.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 2, 'Goinia', Decimal('2.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 2, 'Myingyan', Decimal('3.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 2, 'Rio Claro', Decimal('3.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3, 'Higashiosaka', Decimal('3.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3, 'Matsue', Decimal('3.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3, 'Parbhani', Decimal('3.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4, 'Czestochowa', Decimal('6.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4, 'Fuyu', Decimal('3.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4, 'Kamakura', Decimal('2.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4, 'Tonghae', Decimal('4.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 5, 'Gaziantep', Decimal('7.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 5, 'Mwene-Ditu', Decimal('5.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 5, 'Vicente Lpez', Decimal('7.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 5, 'Zhezqazghan', Decimal('2.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 6, 'Arlington', Decimal('4.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 6, 'Chapra', Decimal('6.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 6, 'Dadu', Decimal('2.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 6, 'Jamalpur', Decimal('4.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 6, 'Kimberley', Decimal('2.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 6, 'Roanoke', Decimal('2.99')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 7, 'Zalantun', Decimal('5.99')),
#  ('ARIZONA BANG', 1, 'Molodetno', Decimal('4.99')),
#  ('ARIZONA BANG', 1, 'Saint-Denis', Decimal('2.99')),
#  ('ARIZONA BANG', 1, 'Springs', Decimal('5.99')),
#  ('ARIZONA BANG', 2, 'Kowloon and New Kowloon', Decimal('7.99')),
#  ('ARIZONA BANG', 2, 'Liepaja', Decimal('7.99')),
#  ('ARIZONA BANG', 2, 'Probolinggo', Decimal('2.99')),
#  ('ARIZONA BANG', 2, 'Szkesfehrvr', Decimal('2.99')),
#  ('ARIZONA BANG', 3, 'guas Lindas de Gois', Decimal('2.99')),
#  ('ARIZONA BANG', 3, 'Hamilton', Decimal('2.99')),
#  ('ARIZONA BANG', 3, 'Osmaniye', Decimal('2.99')),
#  ('ARIZONA BANG', 3, 'Palghat (Palakkad)', Decimal('7.99')),
#  ('ARIZONA BANG', 3, 'Shikarpur', Decimal('4.99')),
#  ('ARIZONA BANG', 3, 'Vijayawada', Decimal('6.99')),
#  ('ARIZONA BANG', 4, 'Davao', Decimal('4.99')),
#  ('ARIZONA BANG', 4, 'Pontianak', Decimal('4.99')),
#  ('ARIZONA BANG', 4, 'Salala', Decimal('2.99')),
#  ('ARIZONA BANG', 5, 'Jalib al-Shuyukh', Decimal('5.99')),
#  ('ARIZONA BANG', 5, 'Nantou', Decimal('2.99')),
#  ('ARIZONA BANG', 6, 'Battambang', Decimal('3.99')),
#  ('ARIZONA BANG', 6, 'Lancaster', Decimal('5.99')),
#  ('ARIZONA BANG', 6, 'Rajkot', Decimal('7.99')),
#  ('ARMAGEDDON LOST', 1, 'Bradford', Decimal('0.99')),
#  ('ARMAGEDDON LOST', 2, 'Ambattur', Decimal('2.99')),
#  ('ARMAGEDDON LOST', 2, 'Cheju', Decimal('1.99')),
#  ('ARMAGEDDON LOST', 2, 'Saint-Denis', Decimal('0.99')),
#  ('ARMAGEDDON LOST', 3, 'Cianjur', Decimal('0.99')),
#  ('ARMAGEDDON LOST', 3, 'Dallas', Decimal('3.99')),
#  ('ARMAGEDDON LOST', 3, 'Dzerzinsk', Decimal('5.99')),
#  ('ARMAGEDDON LOST', 3, 'Hanoi', Decimal('1.99')),
#  ('ARMAGEDDON LOST', 3, 'Nanyang', Decimal('0.99')),
#  ('ARMAGEDDON LOST', 3, 'NDjamna', Decimal('0.99')),
#  ('ARMAGEDDON LOST', 4, 'Rae Bareli', Decimal('3.99')),
#  ('ARMAGEDDON LOST', 4, 'Tallahassee', Decimal('0.99')),
#  ('ARMAGEDDON LOST', 5, 'Luzinia', Decimal('0.99')),
#  ('ARMAGEDDON LOST', 5, 'Trshavn', Decimal('0.99')),
#  ('ARMAGEDDON LOST', 5, 'Uijongbu', Decimal('0.99')),
#  ('ARMAGEDDON LOST', 6, 'Bhavnagar', Decimal('3.99')),
#  ('ARMAGEDDON LOST', 6, 'Hiroshima', Decimal('2.99')),
#  ('ARMAGEDDON LOST', 6, 'Rio Claro', Decimal('1.99')),
#  ('ARMAGEDDON LOST', 6, 'Surakarta', Decimal('4.99')),
#  ('ARMAGEDDON LOST', 7, 'Nakhon Sawan', Decimal('0.99')),
#  ('ARMAGEDDON LOST', 7, 'Szkesfehrvr', Decimal('0.99')),
#  ('ARMY FLINTSTONES', 1, 'Jodhpur', Decimal('2.99')),
#  ('ARMY FLINTSTONES', 2, 'Yamuna Nagar', Decimal('0.99')),
#  ('ARMY FLINTSTONES', 3, 'Kurashiki', Decimal('3.99')),
#  ('ARMY FLINTSTONES', 4, 'Aden', Decimal('0.99')),
#  ('ARMY FLINTSTONES', 4, 'Rae Bareli', Decimal('2.99')),
#  ('ARMY FLINTSTONES', 4, 'Sunnyvale', Decimal('3.99')),
#  ('ARMY FLINTSTONES', 5, 'Boa Vista', Decimal('0.99')),
#  ('ARMY FLINTSTONES', 5, 'Skikda', Decimal('6.99')),
#  ('ARMY FLINTSTONES', 5, 'Sterling Heights', Decimal('0.99')),
#  ('ARMY FLINTSTONES', 5, 'Yuzhou', Decimal('4.99')),
#  ('ARMY FLINTSTONES', 6, 'Cavite', Decimal('0.99')),
#  ('ARMY FLINTSTONES', 6, 'Po', Decimal('3.99')),
#  ('ARMY FLINTSTONES', 6, 'Pune', Decimal('3.99')),
#  ('ARMY FLINTSTONES', 7, 'Kamarhati', Decimal('0.99')),
#  ('ARMY FLINTSTONES', 7, 'Lengshuijiang', Decimal('0.99')),
#  ('ARMY FLINTSTONES', 7, 'Lublin', Decimal('0.99')),
#  ('ARTIST COLDBLOODED', 2, 'Ashdod', Decimal('6.99')),
#  ('ARTIST COLDBLOODED', 2, 'Nha Trang', Decimal('4.99')),
#  ('ARTIST COLDBLOODED', 2, 'Rajkot', Decimal('2.99')),
#  ('ARTIST COLDBLOODED', 3, 'Lubumbashi', Decimal('5.99')),
#  ('ARTIST COLDBLOODED', 4, 'Bijapur', Decimal('5.99')),
#  ('ARTIST COLDBLOODED', 4, 'Juazeiro do Norte', Decimal('6.99')),
#  ('ARTIST COLDBLOODED', 4, 'Ogbomosho', Decimal('6.99')),
#  ('ARTIST COLDBLOODED', 5, 'Tafuna', Decimal('2.99')),
#  ('ARTIST COLDBLOODED', 6, 'Funafuti', Decimal('2.99')),
#  ('ARTIST COLDBLOODED', 6, 'Jastrzebie-Zdrj', Decimal('3.99')),
#  ('ARTIST COLDBLOODED', 6, 'Mosul', Decimal('2.99')),
#  ('ARTIST COLDBLOODED', 6, 'Valencia', Decimal('3.99')),
#  ('ARTIST COLDBLOODED', 7, 'Duisburg', Decimal('2.99')),
#  ('ARTIST COLDBLOODED', 7, 'Hamilton', Decimal('2.99')),
#  ('ARTIST COLDBLOODED', 7, 'Myingyan', Decimal('2.99')),
#  ('ARTIST COLDBLOODED', 7, 'Zaria', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 1, 'al-Manama', Decimal('5.99')),
#  ('ATLANTIS CAUSE', 2, 'Abu Dhabi', Decimal('3.99')),
#  ('ATLANTIS CAUSE', 2, 'Beni-Mellal', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 2, 'Deba Habe', Decimal('5.99')),
#  ('ATLANTIS CAUSE', 2, 'Emmen', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 2, 'guas Lindas de Gois', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 2, 's-Hertogenbosch', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 3, 'Klerksdorp', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 3, 'Pontianak', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 3, 'Sivas', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 3, 'Sogamoso', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 3, 'Tanauan', Decimal('5.99')),
#  ('ATLANTIS CAUSE', 4, 'Ashgabat', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 4, 'Balurghat', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 4, 'Brockton', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 5, 'Duisburg', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 5, 'Pudukkottai', Decimal('3.99')),
#  ('ATLANTIS CAUSE', 5, 'Sambhal', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 5, 'Tabriz', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 6, 'Caracas', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 6, 'Jining', Decimal('3.99')),
#  ('ATLANTIS CAUSE', 7, 'Fuzhou', Decimal('5.99')),
#  ('ATLANTIS CAUSE', 7, 'Jodhpur', Decimal('2.99')),
#  ('ATLANTIS CAUSE', 7, 'Xiangfan', Decimal('3.99')),
#  ('ATTACKS HATE', 1, 'Yangor', Decimal('7.99')),
#  ('ATTACKS HATE', 2, 'Ipoh', Decimal('4.99')),
#  ('ATTACKS HATE', 3, 'Aden', Decimal('7.99')),
#  ('ATTACKS HATE', 3, 'Matsue', Decimal('5.99')),
#  ('ATTACKS HATE', 3, 'Munger (Monghyr)', Decimal('4.99')),
#  ('ATTACKS HATE', 3, 'Owo', Decimal('5.99')),
#  ('ATTACKS HATE', 3, 'Sumy', Decimal('8.99')),
#  ('ATTACKS HATE', 4, 'Banjul', Decimal('8.99')),
#  ('ATTACKS HATE', 4, 'Carmen', Decimal('4.99')),
#  ('ATTACKS HATE', 4, 'Ife', Decimal('4.99')),
#  ('ATTACKS HATE', 5, 'Antofagasta', Decimal('8.99')),
#  ('ATTACKS HATE', 5, 'Bern', Decimal('4.99')),
#  ('ATTACKS HATE', 5, 'Sasebo', Decimal('4.99')),
#  ('ATTACKS HATE', 6, 'Tangail', Decimal('5.99')),
#  ('ATTACKS HATE', 6, 'Ueda', Decimal('4.99')),
#  ('ATTACKS HATE', 7, 'Ashdod', Decimal('5.99')),
#  ('ATTRACTION NEWTON', 1, 'Fontana', Decimal('5.99')),
#  ('ATTRACTION NEWTON', 1, 'Maikop', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 2, 'Batna', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 2, 'Mit Ghamr', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 2, 'Patiala', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 3, 'Maracabo', Decimal('8.99')),
#  ('ATTRACTION NEWTON', 3, 'Monywa', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 3, 'Mukateve', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 3, 'Nagaon', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 3, 'Sincelejo', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 3, 'Southend-on-Sea', Decimal('6.99')),
#  ('ATTRACTION NEWTON', 3, 'Zapopan', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 4, 'Salzburg', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 4, 'Tete', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 4, 'Zeleznogorsk', Decimal('7.99')),
#  ('ATTRACTION NEWTON', 5, 'Amroha', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 5, 'Changzhou', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 5, 'Kimberley', Decimal('8.99')),
#  ('ATTRACTION NEWTON', 5, 'Lengshuijiang', Decimal('6.99')),
#  ('ATTRACTION NEWTON', 6, 'Akishima', Decimal('7.99')),
#  ('ATTRACTION NEWTON', 6, 'Portoviejo', Decimal('8.99')),
#  ('ATTRACTION NEWTON', 7, 'Ezhou', Decimal('7.99')),
#  ('ATTRACTION NEWTON', 7, 'Jakarta', Decimal('4.99')),
#  ('ATTRACTION NEWTON', 7, 'Tongliao', Decimal('5.99')),
#  ('AUTUMN CROW', 2, 'Blumenau', Decimal('9.99')),
#  ('AUTUMN CROW', 2, 'Sincelejo', Decimal('4.99')),
#  ('AUTUMN CROW', 3, 'Fontana', Decimal('9.99')),
#  ('AUTUMN CROW', 3, 'Iwakuni', Decimal('6.99')),
#  ('AUTUMN CROW', 3, 'Stockport', Decimal('10.99')),
#  ('AUTUMN CROW', 4, 'Dallas', Decimal('4.99')),
#  ('AUTUMN CROW', 5, 'Tanshui', Decimal('5.99')),
#  ('AUTUMN CROW', 6, 'Ashgabat', Decimal('9.99')),
#  ('AUTUMN CROW', 6, 'Touliu', Decimal('5.99')),
#  ('AUTUMN CROW', 7, 'Aparecida de Goinia', Decimal('4.99')),
#  ('AUTUMN CROW', 7, 'Basel', Decimal('9.99')),
#  ('BABY HALL', 1, 'Osmaniye', Decimal('4.99')),
#  ('BABY HALL', 2, 'Memphis', Decimal('5.99')),
#  ('BABY HALL', 3, 'Novoterkassk', Decimal('4.99')),
#  ('BABY HALL', 3, 'Surakarta', Decimal('7.99')),
#  ('BABY HALL', 4, 'Ilorin', Decimal('6.99')),
#  ('BABY HALL', 5, 'Lilongwe', Decimal('4.99')),
#  ('BABY HALL', 5, 'Lincoln', Decimal('4.99')),
#  ('BABY HALL', 7, 'San Juan Bautista Tuxtepec', Decimal('4.99')),
#  ('BACKLASH UNDEFEATED', 2, 'Blumenau', Decimal('10.99')),
#  ('BACKLASH UNDEFEATED', 2, 'Cuauhtmoc', Decimal('9.99')),
#  ('BACKLASH UNDEFEATED', 2, 'Elista', Decimal('8.99')),
#  ('BACKLASH UNDEFEATED', 2, 'Pontianak', Decimal('8.99')),
#  ('BACKLASH UNDEFEATED', 2, 'Tarlac', Decimal('7.99')),
#  ('BACKLASH UNDEFEATED', 3, 'Maring', Decimal('6.99')),
#  ('BACKLASH UNDEFEATED', 3, 'Omdurman', Decimal('8.99')),
#  ('BACKLASH UNDEFEATED', 3, 'Uttarpara-Kotrung', Decimal('9.99')),
#  ('BACKLASH UNDEFEATED', 4, 'Bellevue', Decimal('9.99')),
#  ('BACKLASH UNDEFEATED', 4, 'Kaliningrad', Decimal('5.99')),
#  ('BACKLASH UNDEFEATED', 4, 'London', Decimal('9.99')),
#  ('BACKLASH UNDEFEATED', 5, 'Springs', Decimal('4.99')),
#  ('BACKLASH UNDEFEATED', 5, 'Uijongbu', Decimal('5.99')),
#  ('BACKLASH UNDEFEATED', 6, 'Escobar', Decimal('8.99')),
#  ('BACKLASH UNDEFEATED', 6, 'Etawah', Decimal('9.99')),
#  ('BACKLASH UNDEFEATED', 6, 'Jedda', Decimal('4.99')),
#  ('BACKLASH UNDEFEATED', 6, 'Kamyin', Decimal('4.99')),
#  ('BACKLASH UNDEFEATED', 6, 'Kursk', Decimal('9.99')),
#  ('BACKLASH UNDEFEATED', 7, 'Loja', Decimal('9.99')),
#  ('BADMAN DAWN', 1, 'Huixquilucan', Decimal('2.99')),
#  ('BADMAN DAWN', 2, 'Oyo', Decimal('2.99')),
#  ('BADMAN DAWN', 2, 'Zaoyang', Decimal('3.99')),
#  ('BADMAN DAWN', 3, 'Balikesir', Decimal('2.99')),
#  ('BADMAN DAWN', 3, 'Pak Kret', Decimal('3.99')),
#  ('BADMAN DAWN', 3, 'Serpuhov', Decimal('2.99')),
#  ('BADMAN DAWN', 4, 'Abha', Decimal('2.99')),
#  ('BADMAN DAWN', 4, 'Hami', Decimal('5.99')),
#  ('BADMAN DAWN', 4, 'Tanza', Decimal('5.99')),
#  ('BADMAN DAWN', 5, 'Rizhao', Decimal('2.99')),
#  ('BADMAN DAWN', 6, 'Alvorada', Decimal('2.99')),
#  ('BADMAN DAWN', 6, 'Beira', Decimal('4.99')),
#  ('BADMAN DAWN', 6, 'Citt del Vaticano', Decimal('3.99')),
#  ('BADMAN DAWN', 6, 'Fukuyama', Decimal('2.99')),
#  ('BADMAN DAWN', 6, 'Najafabad', Decimal('2.99')),
#  ('BADMAN DAWN', 6, 'Ozamis', Decimal('2.99')),
#  ('BADMAN DAWN', 6, 'Siliguri (Shiliguri)', Decimal('2.99')),
#  ('BADMAN DAWN', 6, 'Tieli', Decimal('4.99')),
#  ('BADMAN DAWN', 7, 'Pak Kret', Decimal('2.99')),
#  ('BADMAN DAWN', 7, 'Simferopol', Decimal('3.99')),
#  ('BADMAN DAWN', 7, 'Soshanguve', Decimal('2.99')),
#  ('BAKED CLEOPATRA', 1, 'Okayama', Decimal('2.99')),
#  ('BAKED CLEOPATRA', 1, 'Phnom Penh', Decimal('2.99')),
#  ('BAKED CLEOPATRA', 1, 'Vila Velha', Decimal('7.99')),
#  ('BAKED CLEOPATRA', 2, 'Bergamo', Decimal('6.99')),
#  ('BAKED CLEOPATRA', 2, 'Garden Grove', Decimal('5.99')),
#  ('BAKED CLEOPATRA', 2, 'Haiphong', Decimal('2.99')),
#  ('BAKED CLEOPATRA', 2, 'San Miguel de Tucumn', Decimal('2.99')),
#  ('BAKED CLEOPATRA', 3, 'Gandhinagar', Decimal('2.99')),
#  ('BAKED CLEOPATRA', 3, 'Madiun', Decimal('2.99')),
#  ('BAKED CLEOPATRA', 3, 'Tarsus', Decimal('2.99')),
#  ('BAKED CLEOPATRA', 4, 'Ourense (Orense)', Decimal('6.99')),
#  ('BAKED CLEOPATRA', 4, 'Santa Rosa', Decimal('6.99')),
#  ('BAKED CLEOPATRA', 5, 'Acua', Decimal('4.99')),
#  ('BAKED CLEOPATRA', 5, 'Valencia', Decimal('7.99')),
#  ('BAKED CLEOPATRA', 6, 'Hiroshima', Decimal('3.99')),
#  ('BAKED CLEOPATRA', 6, 'Hodeida', Decimal('6.99')),
#  ('BALLOON HOMEWARD', 1, 'Datong', Decimal('2.99')),
#  ('BALLOON HOMEWARD', 2, 'Botosani', Decimal('3.99')),
#  ('BALLOON HOMEWARD', 2, 'Livorno', Decimal('3.99')),
#  ('BALLOON HOMEWARD', 2, 'Udaipur', Decimal('5.99')),
#  ('BALLOON HOMEWARD', 2, 'Yerevan', Decimal('2.99')),
#  ('BALLOON HOMEWARD', 3, 'Beira', Decimal('2.99')),
#  ('BALLOON HOMEWARD', 3, 'Bucuresti', Decimal('6.99')),
#  ('BALLOON HOMEWARD', 3, 'Junan', Decimal('4.99')),
#  ('BALLOON HOMEWARD', 3, 'Pak Kret', Decimal('2.99')),
#  ('BALLOON HOMEWARD', 3, 'Roanoke', Decimal('2.99')),
#  ('BALLOON HOMEWARD', 3, 'Witten', Decimal('6.99')),
#  ('BALLOON HOMEWARD', 4, 'Fuyu', Decimal('3.99')),
#  ('BALLOON HOMEWARD', 4, 'Salzburg', Decimal('6.99')),
#  ('BALLOON HOMEWARD', 4, 'Yantai', Decimal('3.99')),
#  ('BALLOON HOMEWARD', 5, 'Araatuba', Decimal('2.99')),
#  ('BALLOON HOMEWARD', 5, 'Beni-Mellal', Decimal('2.99')),
#  ('BALLOON HOMEWARD', 5, 'Plock', Decimal('3.99')),
#  ('BALLOON HOMEWARD', 5, 'Zaoyang', Decimal('2.99')),
#  ('BALLOON HOMEWARD', 6, 'Allende', Decimal('2.99')),
#  ('BALLOON HOMEWARD', 6, 'Cianjur', Decimal('2.99')),
#  ('BALLOON HOMEWARD', 6, 'Vitria de Santo Anto', Decimal('2.99')),
#  ('BALLOON HOMEWARD', 7, 'Binzhou', Decimal('6.99')),
#  ('BALLOON HOMEWARD', 7, 'Yinchuan', Decimal('6.99')),
#  ('BALLROOM MOCKINGBIRD', 1, 'Compton', Decimal('0.99')),
#  ('BALLROOM MOCKINGBIRD', 3, 'Cam Ranh', Decimal('0.99')),
#  ('BALLROOM MOCKINGBIRD', 4, 'Effon-Alaiye', Decimal('0.99')),
#  ('BALLROOM MOCKINGBIRD', 4, 'Omiya', Decimal('0.99')),
#  ('BALLROOM MOCKINGBIRD', 5, 'Valparai', Decimal('0.99')),
#  ('BALLROOM MOCKINGBIRD', 6, 'Malm', Decimal('2.99')),
#  ('BALLROOM MOCKINGBIRD', 6, 'Tychy', Decimal('1.99')),
#  ('BALLROOM MOCKINGBIRD', 7, 'Tarsus', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 2, 'Kaduna', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 2, 'Simferopol', Decimal('4.99')),
#  ('BANGER PINOCCHIO', 2, 'Tama', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 2, 'Vancouver', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 3, 'Katihar', Decimal('3.99')),
#  ('BANGER PINOCCHIO', 3, 'Novoterkassk', Decimal('2.99')),
#  ('BANGER PINOCCHIO', 4, 'Abha', Decimal('1.99')),
#  ('BANGER PINOCCHIO', 4, 'Cabuyao', Decimal('1.99')),
#  ('BANGER PINOCCHIO', 4, 'Cavite', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 4, 'Emeishan', Decimal('2.99')),
#  ('BANGER PINOCCHIO', 4, 'Munger (Monghyr)', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 4, 'Tonghae', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 4, 'Tychy', Decimal('2.99')),
#  ('BANGER PINOCCHIO', 5, 'Ocumare del Tuy', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 6, 'Almirante Brown', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 6, 'Jakarta', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 6, 'Jinchang', Decimal('4.99')),
#  ('BANGER PINOCCHIO', 6, 'Vicente Lpez', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 7, 'Bamenda', Decimal('2.99')),
#  ('BANGER PINOCCHIO', 7, 'Binzhou', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 7, 'Shubra al-Khayma', Decimal('0.99')),
#  ('BANGER PINOCCHIO', 7, 'Siliguri (Shiliguri)', Decimal('0.99')),
#  ('BANG KWAI', 1, 'Boa Vista', Decimal('2.99')),
#  ('BANG KWAI', 1, 'Taizz', Decimal('2.99')),
#  ('BANG KWAI', 6, 'Torren', Decimal('3.99')),
#  ('BANG KWAI', 7, 'Coatzacoalcos', Decimal('3.99')),
#  ('BANG KWAI', 7, 'Nagaon', Decimal('2.99')),
#  ('BANG KWAI', 7, 'Pontianak', Decimal('2.99')),
#  ('BANG KWAI', 7, 'Shikarpur', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 2, 'Abha', Decimal('4.99')),
#  ('BARBARELLA STREETCAR', 2, 'Bucuresti', Decimal('5.99')),
#  ('BARBARELLA STREETCAR', 2, 'Huixquilucan', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 2, 'Meixian', Decimal('5.99')),
#  ('BARBARELLA STREETCAR', 2, 'Miraj', Decimal('3.99')),
#  ('BARBARELLA STREETCAR', 2, 'Tabriz', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 3, 'Hubli-Dharwad', Decimal('3.99')),
#  ('BARBARELLA STREETCAR', 3, 'Moscow', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 4, 'Alvorada', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 4, 'Ashdod', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 4, 'Graz', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 4, 'Kamakura', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 4, 'Qomsheh', Decimal('3.99')),
#  ('BARBARELLA STREETCAR', 4, 'Sal', Decimal('5.99')),
#  ('BARBARELLA STREETCAR', 5, 'Bellevue', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 5, 'Cuernavaca', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 5, 'Gandhinagar', Decimal('3.99')),
#  ('BARBARELLA STREETCAR', 5, 'Ikerre', Decimal('3.99')),
#  ('BARBARELLA STREETCAR', 5, 'Maring', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 5, 'Richmond Hill', Decimal('4.99')),
#  ('BARBARELLA STREETCAR', 5, 'South Hill', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 5, 'Uruapan', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 5, 'Yuncheng', Decimal('5.99')),
#  ('BARBARELLA STREETCAR', 6, 'Ezeiza', Decimal('2.99')),
#  ('BARBARELLA STREETCAR', 7, 'Niznekamsk', Decimal('3.99')),
#  ('BAREFOOT MANCHURIAN', 1, 'Halifax', Decimal('4.99')),
#  ('BAREFOOT MANCHURIAN', 2, 'al-Manama', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', 2, 'Jastrzebie-Zdrj', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', 2, 'Kuwana', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', 2, 'Torren', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', 3, 'Guadalajara', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', 3, 'Madiun', Decimal('3.99')),
#  ('BAREFOOT MANCHURIAN', 4, 'Fukuyama', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', 4, 'Haiphong', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', 4, 'Jelets', Decimal('3.99')),
#  ('BAREFOOT MANCHURIAN', 5, 'Basel', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', 5, 'Kitwe', Decimal('4.99')),
#  ('BAREFOOT MANCHURIAN', 6, 'Adoni', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', 6, 'Le Mans', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', 7, 'Halisahar', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', 7, 'Juazeiro do Norte', Decimal('6.99')),
#  ('BAREFOOT MANCHURIAN', 7, 'Ljubertsy', Decimal('2.99')),
#  ('BAREFOOT MANCHURIAN', 7, 'Pontianak', Decimal('5.99')),
#  ('BASIC EASY', 2, 'Akishima', Decimal('3.99')),
#  ('BASIC EASY', 2, 'Pjatigorsk', Decimal('2.99')),
#  ('BASIC EASY', 2, 'Robamba', Decimal('3.99')),
#  ('BASIC EASY', 3, 'Novi Sad', Decimal('2.99')),
#  ('BASIC EASY', 3, 'Santiago de Compostela', Decimal('2.99')),
#  ('BASIC EASY', 3, 'Shimoga', Decimal('2.99')),
#  ('BASIC EASY', 3, 'Tianjin', Decimal('2.99')),
#  ('BASIC EASY', 4, 'Haining', Decimal('2.99')),
#  ('BASIC EASY', 4, 'Lubumbashi', Decimal('6.99')),
#  ('BASIC EASY', 4, 'Simferopol', Decimal('6.99')),
#  ('BASIC EASY', 5, 'Batman', Decimal('3.99')),
#  ('BASIC EASY', 5, 'Escobar', Decimal('7.99')),
#  ('BASIC EASY', 5, 'Laohekou', Decimal('2.99')),
#  ('BASIC EASY', 5, 'Sincelejo', Decimal('2.99')),
#  ('BASIC EASY', 6, 'Bayugan', Decimal('5.99')),
#  ('BASIC EASY', 6, 'Konotop', Decimal('2.99')),
#  ('BASIC EASY', 6, 'Vancouver', Decimal('5.99')),
#  ('BASIC EASY', 7, 'Imus', Decimal('2.99')),
#  ('BASIC EASY', 7, 'Jurez', Decimal('3.99')),
#  ('BASIC EASY', 7, 'Santa Rosa', Decimal('7.99')),
#  ('BASIC EASY', 7, 'Ziguinchor', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', 1, 'Katihar', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', 2, 'Quilmes', Decimal('3.99')),
#  ('BEACH HEARTBREAKERS', 3, 'Almirante Brown', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', 3, 'Bijapur', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', 3, 'Cuautla', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', 3, 'Kilis', Decimal('4.99')),
#  ('BEACH HEARTBREAKERS', 3, 'Xiangtan', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', 4, 'Novoterkassk', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', 4, 'Pathankot', Decimal('5.99')),
#  ('BEACH HEARTBREAKERS', 5, 'Kingstown', Decimal('5.99')),
#  ('BEACH HEARTBREAKERS', 6, 'Crdoba', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', 6, 'Mysore', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', 7, 'Caracas', Decimal('4.99')),
#  ('BEACH HEARTBREAKERS', 7, 'Hsichuh', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', 7, 'Lungtan', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', 7, 'Ruse', Decimal('2.99')),
#  ('BEACH HEARTBREAKERS', 7, 'Sterling Heights', Decimal('5.99')),
#  ('BEAR GRACELAND', 2, 'Bchar', Decimal('2.99')),
#  ('BEAR GRACELAND', 2, 'Olomouc', Decimal('3.99')),
#  ('BEAR GRACELAND', 2, 'South Hill', Decimal('2.99')),
#  ('BEAR GRACELAND', 3, 'Czestochowa', Decimal('4.99')),
#  ('BEAR GRACELAND', 3, 'Pingxiang', Decimal('3.99')),
#  ('BEAR GRACELAND', 4, 'Addis Abeba', Decimal('2.99')),
#  ('BEAR GRACELAND', 4, 'Angra dos Reis', Decimal('7.99')),
#  ('BEAR GRACELAND', 4, 'Juazeiro do Norte', Decimal('7.99')),
#  ('BEAR GRACELAND', 4, 'Mardan', Decimal('2.99')),
#  ('BEAR GRACELAND', 4, 'Uijongbu', Decimal('2.99')),
#  ('BEAR GRACELAND', 5, 'Pune', Decimal('5.99')),
#  ('BEAR GRACELAND', 5, 'Tabuk', Decimal('6.99')),
#  ('BEAR GRACELAND', 6, 'Bhilwara', Decimal('2.99')),
#  ('BEAR GRACELAND', 6, 'Bhopal', Decimal('2.99')),
#  ('BEAR GRACELAND', 6, 'Nakhon Sawan', Decimal('5.99')),
#  ('BEAR GRACELAND', 6, 'Robamba', Decimal('6.99')),
#  ('BEAR GRACELAND', 7, 'Ahmadnagar', Decimal('6.99')),
#  ('BEAR GRACELAND', 7, 'Lapu-Lapu', Decimal('4.99')),
#  ('BEAR GRACELAND', 7, 'Liaocheng', Decimal('7.99')),
#  ('BEAR GRACELAND', 7, 'Rio Claro', Decimal('4.99')),
#  ('BEAR GRACELAND', 7, 'Shenzhen', Decimal('2.99')),
#  ('BEAR GRACELAND', 7, 'Tiefa', Decimal('3.99')),
#  ('BEAST HUNCHBACK', 1, 'Duisburg', Decimal('4.99')),
#  ('BEAST HUNCHBACK', 2, 'Guadalajara', Decimal('10.99')),
#  ('BEAST HUNCHBACK', 3, 'Nanyang', Decimal('4.99')),
#  ('BEAST HUNCHBACK', 3, 'Zaoyang', Decimal('5.99')),
#  ('BEAST HUNCHBACK', 5, 'Chiayi', Decimal('4.99')),
#  ('BEAST HUNCHBACK', 5, 'Jinzhou', Decimal('6.99')),
#  ('BEAST HUNCHBACK', 6, 'Chandrapur', Decimal('4.99')),
#  ('BEAST HUNCHBACK', 6, 'Faaa', Decimal('4.99')),
#  ('BEAST HUNCHBACK', 6, 'Kolpino', Decimal('7.99')),
#  ('BEAST HUNCHBACK', 7, 'Omiya', Decimal('10.99')),
#  ('BEAST HUNCHBACK', 7, 'Sincelejo', Decimal('8.99')),
#  ('BEAUTY GREASE', 1, 'Firozabad', Decimal('4.99')),
#  ('BEAUTY GREASE', 1, 'Nezahualcyotl', Decimal('6.99')),
#  ('BEAUTY GREASE', 1, 'Zhezqazghan', Decimal('4.99')),
#  ('BEAUTY GREASE', 2, 'Arlington', Decimal('4.99')),
#  ('BEAUTY GREASE', 2, 'Daugavpils', Decimal('8.99')),
#  ('BEAUTY GREASE', 2, 'Dhule (Dhulia)', Decimal('7.99')),
#  ('BEAUTY GREASE', 2, 'Syktyvkar', Decimal('5.99')),
#  ('BEAUTY GREASE', 3, 'Acua', Decimal('4.99')),
#  ('BEAUTY GREASE', 3, 'Barcelona', Decimal('4.99')),
#  ('BEAUTY GREASE', 3, 'Davao', Decimal('4.99')),
#  ('BEAUTY GREASE', 3, 'Lancaster', Decimal('8.99')),
#  ('BEAUTY GREASE', 3, 'Richmond Hill', Decimal('4.99')),
#  ('BEAUTY GREASE', 4, 'Hsichuh', Decimal('4.99')),
#  ('BEAUTY GREASE', 5, 'Bhopal', Decimal('4.99')),
#  ('BEAUTY GREASE', 5, 'Denizli', Decimal('6.99')),
#  ('BEAUTY GREASE', 5, 'Jaffna', Decimal('4.99')),
#  ('BEAUTY GREASE', 5, 'Mwene-Ditu', Decimal('5.99')),
#  ('BEAUTY GREASE', 5, 'Omdurman', Decimal('4.99')),
#  ('BEAUTY GREASE', 5, 'Ziguinchor', Decimal('4.99')),
#  ('BEAUTY GREASE', 6, 'Huixquilucan', Decimal('4.99')),
#  ('BEAUTY GREASE', 6, 'Kursk', Decimal('8.99')),
#  ('BEAUTY GREASE', 7, 'Kamarhati', Decimal('6.99')),
#  ('BEDAZZLED MARRIED', 2, 'Angra dos Reis', Decimal('1.99')),
#  ('BEDAZZLED MARRIED', 2, 'Balurghat', Decimal('0.99')),
#  ('BEDAZZLED MARRIED', 2, 'Myingyan', Decimal('0.99')),
#  ('BEDAZZLED MARRIED', 3, 'Naju', Decimal('0.99')),
#  ('BEDAZZLED MARRIED', 3, 'San Felipe de Puerto Plata', Decimal('0.99')),
#  ('BEDAZZLED MARRIED', 4, 'al-Manama', Decimal('0.99')),
#  ('BEDAZZLED MARRIED', 4, 'Naju', Decimal('0.99')),
#  ('BEDAZZLED MARRIED', 5, 'Baybay', Decimal('0.99')),
#  ('BEDAZZLED MARRIED', 5, 'Duisburg', Decimal('0.99')),
#  ('BEDAZZLED MARRIED', 6, 'Serpuhov', Decimal('0.99')),
#  ('BEDAZZLED MARRIED', 6, 'Shanwei', Decimal('1.99')),
#  ('BEDAZZLED MARRIED', 7, 'Binzhou', Decimal('1.99')),
#  ('BEDAZZLED MARRIED', 7, 'Le Mans', Decimal('1.99')),
#  ('BED HIGHBALL', 2, 'Bhimavaram', Decimal('3.99')),
#  ('BED HIGHBALL', 3, 'Liaocheng', Decimal('2.99')),
#  ('BED HIGHBALL', 6, 'Iligan', Decimal('2.99')),
#  ('BED HIGHBALL', 6, 'Kursk', Decimal('5.99')),
#  ...]

# %% [markdown]
# #### Export db to .sql file

# %%
# !PGPASSWORD=123456 pg_dump -h 127.0.0.1 -U postgres pagila > pagila-star.sql
# Out:
# pg_dump: error: server version: 13.2 (Debian 13.2-1.pgdg100+1); pg_dump version: 12.14 (Ubuntu 12.14-0ubuntu0.20.04.1)
# pg_dump: error: aborting because of server version mismatch
