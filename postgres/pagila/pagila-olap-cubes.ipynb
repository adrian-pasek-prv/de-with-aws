# %%
# Load IPython SQL 
# %load_ext sql

# Specify connection details to postgres database
db_host = '127.0.0.1'
db_name = 'pagila'
db_user = 'postgres'
db_password = '123456'
db_port = '5432'

conn_str = f'postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}'
print(conn_str)
# %sql $conn_str
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# postgresql://postgres:123456@127.0.0.1:5432/pagila
# 'Connected: postgres@pagila'

# %% [markdown]
# ## GROUPING SETS
# - Provide a view of aggregates based on dimensions listed in GROUPING_SETS()
# - Revenue Total, by Month, by Country, by Month & Country All in one shot

# %%
# %%sql
# SELECT dimDate.month,dimStore.country,sum(sales_amount) as revenue
# FROM factSales
# JOIN dimDate  on (dimDate.date_key  = factSales.date_key)
# JOIN dimStore on (dimStore.store_key = factSales.store_key)
# GROUP by grouping sets ((), dimDate.month,  dimStore.country, (dimDate.month,  dimStore.country));
# Out:
#  * postgresql://postgres:***@127.0.0.1:5432/pagila
# 24 rows affected.
# [(None, None, Decimal('67416.51')),
#  (5, 'Canada', Decimal('5716.63')),
#  (7, 'Australia', Decimal('4788.32')),
#  (3, 'Canada', Decimal('5479.06')),
#  (2, 'Australia', Decimal('5043.95')),
#  (5, 'Australia', Decimal('5630.65')),
#  (2, 'Canada', Decimal('5121.02')),
#  (1, 'Australia', Decimal('1471.56')),
#  (4, 'Australia', Decimal('5484.99')),
#  (3, 'Australia', Decimal('5934.80')),
#  (4, 'Canada', Decimal('5274.53')),
#  (1, 'Canada', Decimal('1623.22')),
#  (7, 'Canada', Decimal('4924.33')),
#  (6, 'Canada', Decimal('5550.95')),
#  (6, 'Australia', Decimal('5372.50')),
#  (7, None, Decimal('9712.65')),
#  (1, None, Decimal('3094.78')),
#  (5, None, Decimal('11347.28')),
#  (4, None, Decimal('10759.52')),
#  (2, None, Decimal('10164.97')),
#  (6, None, Decimal('10923.45')),
#  (3, None, Decimal('11413.86')),
#  (None, 'Canada', Decimal('33689.74')),
#  (None, 'Australia', Decimal('33726.77'))]

# %% [markdown]
# ## CUBE - all possible combinations of dims
# - GROUP BY (CUBE()) allows to group by all possible combinations of listed dimensions

# %%
# %%sql
# SELECT dimDate.month,dimStore.country,sum(sales_amount) as revenue
# FROM factSales
# JOIN dimDate     on (dimDate.date_key         = factSales.date_key)
# JOIN dimStore on (dimStore.store_key = factSales.store_key)
# GROUP by cube(dimDate.month,  dimStore.country);
# Out:
#  * postgresql://postgres:***@127.0.0.1:5432/pagila
# 24 rows affected.
# [(None, None, Decimal('67416.51')),
#  (5, 'Canada', Decimal('5716.63')),
#  (7, 'Australia', Decimal('4788.32')),
#  (3, 'Canada', Decimal('5479.06')),
#  (2, 'Australia', Decimal('5043.95')),
#  (5, 'Australia', Decimal('5630.65')),
#  (2, 'Canada', Decimal('5121.02')),
#  (1, 'Australia', Decimal('1471.56')),
#  (4, 'Australia', Decimal('5484.99')),
#  (3, 'Australia', Decimal('5934.80')),
#  (4, 'Canada', Decimal('5274.53')),
#  (1, 'Canada', Decimal('1623.22')),
#  (7, 'Canada', Decimal('4924.33')),
#  (6, 'Canada', Decimal('5550.95')),
#  (6, 'Australia', Decimal('5372.50')),
#  (7, None, Decimal('9712.65')),
#  (1, None, Decimal('3094.78')),
#  (5, None, Decimal('11347.28')),
#  (4, None, Decimal('10759.52')),
#  (2, None, Decimal('10164.97')),
#  (6, None, Decimal('10923.45')),
#  (3, None, Decimal('11413.86')),
#  (None, 'Canada', Decimal('33689.74')),
#  (None, 'Australia', Decimal('33726.77'))]
